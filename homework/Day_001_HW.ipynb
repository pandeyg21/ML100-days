# %% [markdown]
# # 作業1
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# [Two Sigma: Using News to Predict Stock Movements](https://www.kaggle.com/c/two-sigma-financial-news/data)
# 1. 你選的這組資料為何重要
#     I am hoping to predict future stock price returns based on the market and news data.
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     * Market data is provided by Intrinio. It contains financial market information sucj as opening price, closing price, trading volume, calculated returns, etc.
#     * News data is provided by Thomas Reuters. It contains information about news articles/alerts published about assets, such as article details, sentimnt, and other commentrary.
# 3. 蒐集而來的資料型態為何
#     * Market data: The data includes a subset of US-listed instruments. The set included instruments changes daily and is determined base on the amount traded and the availability of information. This means that there may be instruments that enter and leave this subsetof data. There may therefore by gaps in the data provided, and this soes not necessarily imply that data does not exist.
#     * News data: The data contains information at both the news article level and asset level.
# 4. 這組資料想解決的問題如何評估
#     I would like to use regression to approach this problem.

# %% [markdown]
# # 作業2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     I would define performance as the income per month. As to improve performance, we have to analyze the time and area that woud increase the amount of customers.
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     I would collect GPS  positions via phone(eg. area, how long it takes to have customer, income per trip, route of the trip)
# 3. 蒐集而來的資料型態為何
#     Data type would be sequemtial data.
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     I would use regression to analyze this problem.

# %% [markdown]
# # 作業3

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y_true, y_pred):
    MSE = np.sum((y_true - y_pred)**2) / len(y_true)
    return MSE

def mean_absolute_error(y_true, y_pred):
    MAE = np.sum(abs(y_true - y_pred)) / len(y_true)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 272.604
# The Mean absolute error is 13.273
